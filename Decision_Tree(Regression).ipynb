# %% [markdown]
# <a href="https://colab.research.google.com/github/Hellokrrish/Machine-Learning/blob/main/Decision_Tree(Regression).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import fetch_california_housing
data=fetch_california_housing()
df=pd.DataFrame(data.data,columns=data.feature_names)
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
df['price']=data.target

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  price
# ...

# %%
df=df.sample(frac=0.20)

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 5852   3.5875      39.0  3.667279   1.036765      1202.0  2.209559     34.17
# 1633   2.4444      20.0  6.333333   0.866667        31.0  2.066667     37.88
# 4644   2.8202      24.0  3.136150   1.063380      1268.0  2.976526     34.06
# 5981   3.5072      29.0  5.154135   0.917293      2477.0  4.656015     34.10
# 15432  2.0625      22.0  3.961409   1.036913      1472.0  2.469799     33.20
# ...       ...       ...       ...        ...         ...       ...       ...
# 8592   4.4271      44.0  5.514170   0.959514       709.0  2.870445     33.88
# 6086   3.2469      33.0  4.560302   1.005025      2257.0  2.835427     34.08
# 2004   2.1094      52.0  2.059524   1.035714       401.0  4.773810     36.74
# 19686  1.6719      41.0  3.908012   0.916914       856.0  2.540059     39.13
# 16750  2.4830      44.0  3.714286   1.040816       339.0  3.459184     37.71
#
#        Longitude
# 5852     -118.32
# ...

# %%
y
# Out:
# 5852     2.50000
# 1633     4.75000
# 4644     5.00001
# 5981     1.21900
# 15432    1.24500
#           ...
# 8592     3.36200
# 6086     2.06900
# 2004     0.75000
# 19686    0.64100
# 16750    2.14300
# Name: price, Length: 4128, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model
# Out:
# DecisionTreeRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([3.593, 1.076, 1.635, ..., 1.469, 3.204, 2.932])

# %%
# evoluation matrics:
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.4673337938821305

# %%
parameter={
    'criterion':['squared_error','absolute_error','poisson'],
    'splitter':['best','random'],
    'max_depth':[1,2,3,4,6,8],
    'max_features':['sqrt','log2']
}
reg=DecisionTreeRegressor()

# %%
from sklearn.model_selection import GridSearchCV
model=GridSearchCV(reg,param_grid=parameter,cv=5,scoring='neg_mean_squared_error')
model
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'max_depth': [1, 2, 3, 4, 6, 8],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
model.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'max_depth': [1, 2, 3, 4, 6, 8],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
model.best_params_
# Out:
# {'criterion': 'poisson',
#  'max_depth': 6,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %%
model.best_score_
# Out:
# -0.5804053101627921

# %%
final_model=DecisionTreeRegressor(criterion="squared_error",max_depth=8)
final_model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=8)

# %%
from sklearn import tree
plt.figure(figsize=(12,10))
tree.plot_tree(final_model,filled=True)
plt.show()

# %%
y_pred=model.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.5575017547898503
