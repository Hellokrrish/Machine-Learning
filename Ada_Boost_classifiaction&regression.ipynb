# %% [markdown]
# <a href="https://colab.research.google.com/github/Hellokrrish/Machine-Learning/blob/main/Ada_Boost_classifiaction%26regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier,AdaBoostRegressor
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,r2_score

import warnings
warnings.filterwarnings('ignore')

# %%
x,y=make_classification(n_samples=1000,n_features=20,n_classes=2,random_state=1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=1)

# %%
classifier=AdaBoostClassifier()

# %%
classifier.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred=classifier.predict(x_test)
print('accuracy_score',accuracy_score(y_test,y_pred))
print('classification_report',classification_report(y_test,y_pred))
print('confusion_matrix',confusion_matrix(y_test,y_pred))
print('r2_score',r2_score(y_test,y_pred))
# Out:
# accuracy_score 0.8090909090909091
# classification_report               precision    recall  f1-score   support
#
#            0       0.78      0.82      0.80       154
#            1       0.83      0.80      0.82       176
#
#     accuracy                           0.81       330
#    macro avg       0.81      0.81      0.81       330
# weighted avg       0.81      0.81      0.81       330
#
# confusion_matrix [[126  28]
#  [ 35 141]]
# r2_score 0.23295454545454553

# %%
# Hyper_paramertuning:
from sklearn.model_selection import GridSearchCV
param_grid={'n_estimators':[50,100,200],
            'learning_rate':[0.001,0.1,1,1.5,2,2.5],
            'algorithm':['SAMME','SAMME.R']
            }
ada=AdaBoostClassifier()
clf=GridSearchCV(estimator=ada,param_grid=param_grid,cv=5,verbose=3)
clf
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(),
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.001, 0.1, 1, 1.5, 2, 2.5],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
clf.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END algorithm=SAMME, learning_rate=0.001, n_estimators=50;, score=0.881 total time=   0.4s
# [CV 2/5] END algorithm=SAMME, learning_rate=0.001, n_estimators=50;, score=0.903 total time=   0.4s
# [CV 3/5] END algorithm=SAMME, learning_rate=0.001, n_estimators=50;, score=0.843 total time=   0.3s
# [CV 4/5] END algorithm=SAMME, learning_rate=0.001, n_estimators=50;, score=0.813 total time=   0.3s
# [CV 5/5] END algorithm=SAMME, learning_rate=0.001, n_estimators=50;, score=0.813 total time=   0.3s
# [CV 1/5] END algorithm=SAMME, learning_rate=0.001, n_estimators=100;, score=0.881 total time=   0.6s
# [CV 2/5] END algorithm=SAMME, learning_rate=0.001, n_estimators=100;, score=0.903 total time=   0.6s
# [CV 3/5] END algorithm=SAMME, learning_rate=0.001, n_estimators=100;, score=0.843 total time=   0.5s
# [CV 4/5] END algorithm=SAMME, learning_rate=0.001, n_estimators=100;, score=0.813 total time=   0.5s
# [CV 5/5] END algorithm=SAMME, learning_rate=0.001, n_estimators=100;, score=0.813 total time=   0.5s
# [CV 1/5] END algorithm=SAMME, learning_rate=0.001, n_estimators=200;, score=0.881 total time=   1.1s
# [CV 2/5] END algorithm=SAMME, learning_rate=0.001, n_estimators=200;, score=0.903 total time=   1.0s
# [CV 3/5] END algorithm=SAMME, learning_rate=0.001, n_estimators=200;, score=0.843 total time=   0.7s
# [CV 4/5] END algorithm=SAMME, learning_rate=0.001, n_estimators=200;, score=0.813 total time=   0.7s
# [CV 5/5] END algorithm=SAMME, learning_rate=0.001, n_estimators=200;, score=0.813 total time=   0.7s
# [CV 1/5] END algorithm=SAMME, learning_rate=0.1, n_estimators=50;, score=0.881 total time=   0.2s
# [CV 2/5] END algorithm=SAMME, learning_rate=0.1, n_estimators=50;, score=0.903 total time=   0.2s
# [CV 3/5] END algorithm=SAMME, learning_rate=0.1, n_estimators=50;, score=0.843 total time=   0.2s
# [CV 4/5] END algorithm=SAMME, learning_rate=0.1, n_estimators=50;, score=0.858 total time=   0.2s
# [CV 5/5] END algorithm=SAMME, learning_rate=0.1, n_estimators=50;, score=0.813 total time=   0.2s
# [CV 1/5] END algorithm=SAMME, learning_rate=0.1, n_estimators=100;, score=0.881 total time=   0.4s
# [CV 2/5] END algorithm=SAMME, learning_rate=0.1, n_estimators=100;, score=0.903 total time=   0.4s
# [CV 3/5] END algorithm=SAMME, learning_rate=0.1, n_estimators=100;, score=0.843 total time=   0.4s
# [CV 4/5] END algorithm=SAMME, learning_rate=0.1, n_estimators=100;, score=0.858 total time=   0.4s
# [CV 5/5] END algorithm=SAMME, learning_rate=0.1, n_estimators=100;, score=0.813 total time=   0.4s
# [CV 1/5] END algorithm=SAMME, learning_rate=0.1, n_estimators=200;, score=0.888 total time=   0.7s
# [CV 2/5] END algorithm=SAMME, learning_rate=0.1, n_estimators=200;, score=0.903 total time=   0.7s
# [CV 3/5] END algorithm=SAMME, learning_rate=0.1, n_estimators=200;, score=0.851 total time=   0.7s
# [CV 4/5] END algorithm=SAMME, learning_rate=0.1, n_estimators=200;, score=0.858 total time=   0.7s
# [CV 5/5] END algorithm=SAMME, learning_rate=0.1, n_estimators=200;, score=0.821 total time=   0.7s
# [CV 1/5] END algorithm=SAMME, learning_rate=1, n_estimators=50;, score=0.873 total time=   0.2s
# [CV 2/5] END algorithm=SAMME, learning_rate=1, n_estimators=50;, score=0.896 total time=   0.2s
# [CV 3/5] END algorithm=SAMME, learning_rate=1, n_estimators=50;, score=0.851 total time=   0.2s
# [CV 4/5] END algorithm=SAMME, learning_rate=1, n_estimators=50;, score=0.799 total time=   0.2s
# [CV 5/5] END algorithm=SAMME, learning_rate=1, n_estimators=50;, score=0.821 total time=   0.2s
# [CV 1/5] END algorithm=SAMME, learning_rate=1, n_estimators=100;, score=0.873 total time=   0.5s
# [CV 2/5] END algorithm=SAMME, learning_rate=1, n_estimators=100;, score=0.888 total time=   0.5s
# [CV 3/5] END algorithm=SAMME, learning_rate=1, n_estimators=100;, score=0.866 total time=   0.5s
# [CV 4/5] END algorithm=SAMME, learning_rate=1, n_estimators=100;, score=0.806 total time=   0.6s
# [CV 5/5] END algorithm=SAMME, learning_rate=1, n_estimators=100;, score=0.828 total time=   0.6s
# [CV 1/5] END algorithm=SAMME, learning_rate=1, n_estimators=200;, score=0.873 total time=   1.1s
# [CV 2/5] END algorithm=SAMME, learning_rate=1, n_estimators=200;, score=0.843 total time=   0.7s
# [CV 3/5] END algorithm=SAMME, learning_rate=1, n_estimators=200;, score=0.851 total time=   0.7s
# [CV 4/5] END algorithm=SAMME, learning_rate=1, n_estimators=200;, score=0.821 total time=   0.7s
# [CV 5/5] END algorithm=SAMME, learning_rate=1, n_estimators=200;, score=0.821 total time=   0.7s
# [CV 1/5] END algorithm=SAMME, learning_rate=1.5, n_estimators=50;, score=0.866 total time=   0.2s
# [CV 2/5] END algorithm=SAMME, learning_rate=1.5, n_estimators=50;, score=0.858 total time=   0.2s
# [CV 3/5] END algorithm=SAMME, learning_rate=1.5, n_estimators=50;, score=0.843 total time=   0.2s
# [CV 4/5] END algorithm=SAMME, learning_rate=1.5, n_estimators=50;, score=0.828 total time=   0.2s
# [CV 5/5] END algorithm=SAMME, learning_rate=1.5, n_estimators=50;, score=0.821 total time=   0.2s
# [CV 1/5] END algorithm=SAMME, learning_rate=1.5, n_estimators=100;, score=0.851 total time=   0.4s
# [CV 2/5] END algorithm=SAMME, learning_rate=1.5, n_estimators=100;, score=0.881 total time=   0.4s
# [CV 3/5] END algorithm=SAMME, learning_rate=1.5, n_estimators=100;, score=0.806 total time=   0.4s
# [CV 4/5] END algorithm=SAMME, learning_rate=1.5, n_estimators=100;, score=0.799 total time=   0.4s
# [CV 5/5] END algorithm=SAMME, learning_rate=1.5, n_estimators=100;, score=0.791 total time=   0.4s
# [CV 1/5] END algorithm=SAMME, learning_rate=1.5, n_estimators=200;, score=0.866 total time=   0.7s
# [CV 2/5] END algorithm=SAMME, learning_rate=1.5, n_estimators=200;, score=0.866 total time=   0.7s
# [CV 3/5] END algorithm=SAMME, learning_rate=1.5, n_estimators=200;, score=0.821 total time=   0.8s
# [CV 4/5] END algorithm=SAMME, learning_rate=1.5, n_estimators=200;, score=0.784 total time=   0.7s
# [CV 5/5] END algorithm=SAMME, learning_rate=1.5, n_estimators=200;, score=0.813 total time=   0.7s
# [CV 1/5] END algorithm=SAMME, learning_rate=2, n_estimators=50;, score=0.403 total time=   0.2s
# [CV 2/5] END algorithm=SAMME, learning_rate=2, n_estimators=50;, score=0.313 total time=   0.2s
# [CV 3/5] END algorithm=SAMME, learning_rate=2, n_estimators=50;, score=0.366 total time=   0.2s
# [CV 4/5] END algorithm=SAMME, learning_rate=2, n_estimators=50;, score=0.396 total time=   0.3s
# [CV 5/5] END algorithm=SAMME, learning_rate=2, n_estimators=50;, score=0.179 total time=   0.3s
# [CV 1/5] END algorithm=SAMME, learning_rate=2, n_estimators=100;, score=0.530 total time=   0.5s
# [CV 2/5] END algorithm=SAMME, learning_rate=2, n_estimators=100;, score=0.560 total time=   0.6s
# [CV 3/5] END algorithm=SAMME, learning_rate=2, n_estimators=100;, score=0.388 total time=   0.5s
# [CV 4/5] END algorithm=SAMME, learning_rate=2, n_estimators=100;, score=0.478 total time=   0.6s
# [CV 5/5] END algorithm=SAMME, learning_rate=2, n_estimators=100;, score=0.590 total time=   0.6s
# [CV 1/5] END algorithm=SAMME, learning_rate=2, n_estimators=200;, score=0.612 total time=   0.8s
# [CV 2/5] END algorithm=SAMME, learning_rate=2, n_estimators=200;, score=0.560 total time=   0.8s
# [CV 3/5] END algorithm=SAMME, learning_rate=2, n_estimators=200;, score=0.612 total time=   0.8s
# [CV 4/5] END algorithm=SAMME, learning_rate=2, n_estimators=200;, score=0.799 total time=   0.7s
# [CV 5/5] END algorithm=SAMME, learning_rate=2, n_estimators=200;, score=0.582 total time=   0.7s
# [CV 1/5] END algorithm=SAMME, learning_rate=2.5, n_estimators=50;, score=0.858 total time=   0.2s
# [CV 2/5] END algorithm=SAMME, learning_rate=2.5, n_estimators=50;, score=0.888 total time=   0.2s
# [CV 3/5] END algorithm=SAMME, learning_rate=2.5, n_estimators=50;, score=0.843 total time=   0.2s
# [CV 4/5] END algorithm=SAMME, learning_rate=2.5, n_estimators=50;, score=0.799 total time=   0.2s
# [CV 5/5] END algorithm=SAMME, learning_rate=2.5, n_estimators=50;, score=0.843 total time=   0.2s
# [CV 1/5] END algorithm=SAMME, learning_rate=2.5, n_estimators=100;, score=0.858 total time=   0.4s
# [CV 2/5] END algorithm=SAMME, learning_rate=2.5, n_estimators=100;, score=0.896 total time=   0.4s
# [CV 3/5] END algorithm=SAMME, learning_rate=2.5, n_estimators=100;, score=0.843 total time=   0.4s
# [CV 4/5] END algorithm=SAMME, learning_rate=2.5, n_estimators=100;, score=0.799 total time=   0.4s
# [CV 5/5] END algorithm=SAMME, learning_rate=2.5, n_estimators=100;, score=0.843 total time=   0.4s
# [CV 1/5] END algorithm=SAMME, learning_rate=2.5, n_estimators=200;, score=0.858 total time=   0.7s
# [CV 2/5] END algorithm=SAMME, learning_rate=2.5, n_estimators=200;, score=0.896 total time=   0.8s
# [CV 3/5] END algorithm=SAMME, learning_rate=2.5, n_estimators=200;, score=0.843 total time=   0.8s
# [CV 4/5] END algorithm=SAMME, learning_rate=2.5, n_estimators=200;, score=0.799 total time=   0.8s
# [CV 5/5] END algorithm=SAMME, learning_rate=2.5, n_estimators=200;, score=0.843 total time=   0.9s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=50;, score=0.881 total time=   0.3s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=50;, score=0.903 total time=   0.3s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=50;, score=0.843 total time=   0.3s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=50;, score=0.813 total time=   0.3s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=50;, score=0.813 total time=   0.3s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=100;, score=0.881 total time=   0.6s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=100;, score=0.903 total time=   0.6s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=100;, score=0.843 total time=   0.6s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=100;, score=0.813 total time=   0.4s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=100;, score=0.813 total time=   0.4s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=200;, score=0.881 total time=   0.8s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=200;, score=0.903 total time=   0.8s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=200;, score=0.843 total time=   0.8s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=200;, score=0.813 total time=   0.8s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=200;, score=0.813 total time=   0.8s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=50;, score=0.881 total time=   0.2s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=50;, score=0.896 total time=   0.2s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=50;, score=0.851 total time=   0.2s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=50;, score=0.873 total time=   0.2s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=50;, score=0.813 total time=   0.2s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=100;, score=0.866 total time=   0.4s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=100;, score=0.903 total time=   0.4s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=100;, score=0.858 total time=   0.4s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=100;, score=0.858 total time=   0.4s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=100;, score=0.821 total time=   0.4s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200;, score=0.858 total time=   0.8s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200;, score=0.881 total time=   0.8s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200;, score=0.843 total time=   0.8s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200;, score=0.828 total time=   0.9s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200;, score=0.828 total time=   1.1s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=50;, score=0.866 total time=   0.3s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=50;, score=0.888 total time=   0.3s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=50;, score=0.858 total time=   0.3s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=50;, score=0.799 total time=   0.3s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=50;, score=0.821 total time=   0.3s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=100;, score=0.851 total time=   0.5s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=100;, score=0.828 total time=   0.4s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=100;, score=0.806 total time=   0.4s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=100;, score=0.791 total time=   0.4s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=100;, score=0.813 total time=   0.4s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=200;, score=0.828 total time=   0.8s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=200;, score=0.836 total time=   0.8s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=200;, score=0.791 total time=   0.8s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=200;, score=0.799 total time=   0.8s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=1, n_estimators=200;, score=0.806 total time=   0.8s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=1.5, n_estimators=50;, score=0.836 total time=   0.2s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=1.5, n_estimators=50;, score=0.873 total time=   0.3s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=1.5, n_estimators=50;, score=0.836 total time=   0.2s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=1.5, n_estimators=50;, score=0.761 total time=   0.2s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=1.5, n_estimators=50;, score=0.806 total time=   0.3s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=1.5, n_estimators=100;, score=0.851 total time=   0.8s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=1.5, n_estimators=100;, score=0.843 total time=   0.9s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=1.5, n_estimators=100;, score=0.836 total time=   0.9s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=1.5, n_estimators=100;, score=0.761 total time=   1.3s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=1.5, n_estimators=100;, score=0.813 total time=   1.8s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=1.5, n_estimators=200;, score=0.843 total time=   2.3s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=1.5, n_estimators=200;, score=0.828 total time=   1.4s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=1.5, n_estimators=200;, score=0.873 total time=   1.3s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=1.5, n_estimators=200;, score=0.784 total time=   1.3s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=1.5, n_estimators=200;, score=0.791 total time=   1.6s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=50;, score=0.164 total time=   0.5s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=50;, score=0.157 total time=   0.3s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=50;, score=0.127 total time=   0.3s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=50;, score=0.179 total time=   0.4s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=50;, score=0.172 total time=   0.3s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=100;, score=0.209 total time=   0.6s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=100;, score=0.172 total time=   0.6s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=100;, score=0.209 total time=   1.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=100;, score=0.224 total time=   0.6s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=100;, score=0.201 total time=   0.5s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=200;, score=0.493 total time=   1.1s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=200;, score=0.515 total time=   0.9s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=200;, score=0.478 total time=   0.8s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=200;, score=0.590 total time=   0.8s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=2, n_estimators=200;, score=0.627 total time=   0.8s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=2.5, n_estimators=50;, score=0.567 total time=   0.2s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=2.5, n_estimators=50;, score=0.590 total time=   0.2s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=2.5, n_estimators=50;, score=0.836 total time=   0.2s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=2.5, n_estimators=50;, score=0.590 total time=   0.2s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=2.5, n_estimators=50;, score=0.843 total time=   0.2s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=2.5, n_estimators=100;, score=0.567 total time=   0.4s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=2.5, n_estimators=100;, score=0.881 total time=   0.4s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=2.5, n_estimators=100;, score=0.791 total time=   0.4s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=2.5, n_estimators=100;, score=0.761 total time=   0.4s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=2.5, n_estimators=100;, score=0.843 total time=   0.4s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=2.5, n_estimators=200;, score=0.567 total time=   0.8s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=2.5, n_estimators=200;, score=0.881 total time=   0.8s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=2.5, n_estimators=200;, score=0.791 total time=   0.7s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=2.5, n_estimators=200;, score=0.761 total time=   0.8s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=2.5, n_estimators=200;, score=0.828 total time=   0.8s
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(),
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.001, 0.1, 1, 1.5, 2, 2.5],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
clf.best_params_
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 0.1, 'n_estimators': 200}

# %%
clf.best_score_
# Out:
# 0.864179104477612

# %%
# Regression:
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import r2_score

# %%
x,y=make_regression(n_samples=1000,n_features=2,noise=10,random_state=1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=1)

# %%
reg=AdaBoostRegressor()
reg
# Out:
# AdaBoostRegressor()

# %%
reg.fit(x_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
y_pred=reg.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.9533172600154046

# %%
# Hyper_paramertuning:
from sklearn.model_selection import GridSearchCV
param_grid={'n_estimators':[50,100,200],
            'learning_rate':[0.001,0.1,1,1.5,2,2.5],
            'loss':['linear','square']
            }
adr=AdaBoostRegressor()
reg=GridSearchCV(estimator=adr,param_grid=param_grid,cv=5,verbose=3)
reg
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostRegressor(),
#              param_grid={'learning_rate': [0.001, 0.1, 1, 1.5, 2, 2.5],
#                          'loss': ['linear', 'square'],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
reg.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END learning_rate=0.001, loss=linear, n_estimators=50;, score=0.942 total time=   0.2s
# [CV 2/5] END learning_rate=0.001, loss=linear, n_estimators=50;, score=0.933 total time=   0.2s
# [CV 3/5] END learning_rate=0.001, loss=linear, n_estimators=50;, score=0.941 total time=   0.2s
# [CV 4/5] END learning_rate=0.001, loss=linear, n_estimators=50;, score=0.934 total time=   0.2s
# [CV 5/5] END learning_rate=0.001, loss=linear, n_estimators=50;, score=0.935 total time=   0.2s
# [CV 1/5] END learning_rate=0.001, loss=linear, n_estimators=100;, score=0.940 total time=   0.3s
# [CV 2/5] END learning_rate=0.001, loss=linear, n_estimators=100;, score=0.936 total time=   0.3s
# [CV 3/5] END learning_rate=0.001, loss=linear, n_estimators=100;, score=0.943 total time=   0.3s
# [CV 4/5] END learning_rate=0.001, loss=linear, n_estimators=100;, score=0.934 total time=   0.3s
# [CV 5/5] END learning_rate=0.001, loss=linear, n_estimators=100;, score=0.936 total time=   0.3s
# [CV 1/5] END learning_rate=0.001, loss=linear, n_estimators=200;, score=0.941 total time=   0.7s
# [CV 2/5] END learning_rate=0.001, loss=linear, n_estimators=200;, score=0.934 total time=   0.6s
# [CV 3/5] END learning_rate=0.001, loss=linear, n_estimators=200;, score=0.945 total time=   0.4s
# [CV 4/5] END learning_rate=0.001, loss=linear, n_estimators=200;, score=0.936 total time=   0.4s
# [CV 5/5] END learning_rate=0.001, loss=linear, n_estimators=200;, score=0.938 total time=   0.4s
# [CV 1/5] END learning_rate=0.001, loss=square, n_estimators=50;, score=0.942 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, loss=square, n_estimators=50;, score=0.934 total time=   0.1s
# [CV 3/5] END learning_rate=0.001, loss=square, n_estimators=50;, score=0.949 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, loss=square, n_estimators=50;, score=0.934 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, loss=square, n_estimators=50;, score=0.935 total time=   0.1s
# [CV 1/5] END learning_rate=0.001, loss=square, n_estimators=100;, score=0.940 total time=   0.2s
# [CV 2/5] END learning_rate=0.001, loss=square, n_estimators=100;, score=0.936 total time=   0.2s
# [CV 3/5] END learning_rate=0.001, loss=square, n_estimators=100;, score=0.945 total time=   0.2s
# [CV 4/5] END learning_rate=0.001, loss=square, n_estimators=100;, score=0.936 total time=   0.2s
# [CV 5/5] END learning_rate=0.001, loss=square, n_estimators=100;, score=0.938 total time=   0.2s
# [CV 1/5] END learning_rate=0.001, loss=square, n_estimators=200;, score=0.941 total time=   0.4s
# [CV 2/5] END learning_rate=0.001, loss=square, n_estimators=200;, score=0.934 total time=   0.5s
# [CV 3/5] END learning_rate=0.001, loss=square, n_estimators=200;, score=0.945 total time=   0.4s
# [CV 4/5] END learning_rate=0.001, loss=square, n_estimators=200;, score=0.937 total time=   0.4s
# [CV 5/5] END learning_rate=0.001, loss=square, n_estimators=200;, score=0.938 total time=   0.4s
# [CV 1/5] END learning_rate=0.1, loss=linear, n_estimators=50;, score=0.950 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, loss=linear, n_estimators=50;, score=0.940 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, loss=linear, n_estimators=50;, score=0.955 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, loss=linear, n_estimators=50;, score=0.945 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, loss=linear, n_estimators=50;, score=0.943 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, loss=linear, n_estimators=100;, score=0.955 total time=   0.2s
# [CV 2/5] END learning_rate=0.1, loss=linear, n_estimators=100;, score=0.948 total time=   0.2s
# [CV 3/5] END learning_rate=0.1, loss=linear, n_estimators=100;, score=0.958 total time=   0.2s
# [CV 4/5] END learning_rate=0.1, loss=linear, n_estimators=100;, score=0.944 total time=   0.2s
# [CV 5/5] END learning_rate=0.1, loss=linear, n_estimators=100;, score=0.947 total time=   0.2s
# [CV 1/5] END learning_rate=0.1, loss=linear, n_estimators=200;, score=0.959 total time=   0.4s
# [CV 2/5] END learning_rate=0.1, loss=linear, n_estimators=200;, score=0.949 total time=   0.4s
# [CV 3/5] END learning_rate=0.1, loss=linear, n_estimators=200;, score=0.961 total time=   0.4s
# [CV 4/5] END learning_rate=0.1, loss=linear, n_estimators=200;, score=0.950 total time=   0.4s
# [CV 5/5] END learning_rate=0.1, loss=linear, n_estimators=200;, score=0.952 total time=   0.4s
# [CV 1/5] END learning_rate=0.1, loss=square, n_estimators=50;, score=0.956 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, loss=square, n_estimators=50;, score=0.944 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, loss=square, n_estimators=50;, score=0.955 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, loss=square, n_estimators=50;, score=0.945 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, loss=square, n_estimators=50;, score=0.947 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, loss=square, n_estimators=100;, score=0.958 total time=   0.3s
# [CV 2/5] END learning_rate=0.1, loss=square, n_estimators=100;, score=0.944 total time=   0.3s
# [CV 3/5] END learning_rate=0.1, loss=square, n_estimators=100;, score=0.960 total time=   0.3s
# [CV 4/5] END learning_rate=0.1, loss=square, n_estimators=100;, score=0.953 total time=   0.3s
# [CV 5/5] END learning_rate=0.1, loss=square, n_estimators=100;, score=0.953 total time=   0.3s
# [CV 1/5] END learning_rate=0.1, loss=square, n_estimators=200;, score=0.961 total time=   1.0s
# [CV 2/5] END learning_rate=0.1, loss=square, n_estimators=200;, score=0.947 total time=   1.2s
# [CV 3/5] END learning_rate=0.1, loss=square, n_estimators=200;, score=0.966 total time=   0.6s
# [CV 4/5] END learning_rate=0.1, loss=square, n_estimators=200;, score=0.955 total time=   1.0s
# [CV 5/5] END learning_rate=0.1, loss=square, n_estimators=200;, score=0.960 total time=   0.8s
# [CV 1/5] END learning_rate=1, loss=linear, n_estimators=50;, score=0.965 total time=   0.2s
# [CV 2/5] END learning_rate=1, loss=linear, n_estimators=50;, score=0.955 total time=   0.1s
# [CV 3/5] END learning_rate=1, loss=linear, n_estimators=50;, score=0.967 total time=   0.1s
# [CV 4/5] END learning_rate=1, loss=linear, n_estimators=50;, score=0.960 total time=   0.2s
# [CV 5/5] END learning_rate=1, loss=linear, n_estimators=50;, score=0.963 total time=   0.3s
# [CV 1/5] END learning_rate=1, loss=linear, n_estimators=100;, score=0.964 total time=   0.3s
# [CV 2/5] END learning_rate=1, loss=linear, n_estimators=100;, score=0.959 total time=   0.4s
# [CV 3/5] END learning_rate=1, loss=linear, n_estimators=100;, score=0.970 total time=   0.3s
# [CV 4/5] END learning_rate=1, loss=linear, n_estimators=100;, score=0.963 total time=   0.4s
# [CV 5/5] END learning_rate=1, loss=linear, n_estimators=100;, score=0.964 total time=   0.5s
# [CV 1/5] END learning_rate=1, loss=linear, n_estimators=200;, score=0.966 total time=   0.4s
# [CV 2/5] END learning_rate=1, loss=linear, n_estimators=200;, score=0.959 total time=   0.7s
# [CV 3/5] END learning_rate=1, loss=linear, n_estimators=200;, score=0.971 total time=   1.4s
# [CV 4/5] END learning_rate=1, loss=linear, n_estimators=200;, score=0.965 total time=   1.7s
# [CV 5/5] END learning_rate=1, loss=linear, n_estimators=200;, score=0.967 total time=   0.9s
# [CV 1/5] END learning_rate=1, loss=square, n_estimators=50;, score=0.967 total time=   0.2s
# [CV 2/5] END learning_rate=1, loss=square, n_estimators=50;, score=0.957 total time=   0.3s
# [CV 3/5] END learning_rate=1, loss=square, n_estimators=50;, score=0.973 total time=   0.3s
# [CV 4/5] END learning_rate=1, loss=square, n_estimators=50;, score=0.964 total time=   0.3s
# [CV 5/5] END learning_rate=1, loss=square, n_estimators=50;, score=0.964 total time=   0.3s
# [CV 1/5] END learning_rate=1, loss=square, n_estimators=100;, score=0.968 total time=   0.5s
# [CV 2/5] END learning_rate=1, loss=square, n_estimators=100;, score=0.959 total time=   0.5s
# [CV 3/5] END learning_rate=1, loss=square, n_estimators=100;, score=0.973 total time=   1.0s
# [CV 4/5] END learning_rate=1, loss=square, n_estimators=100;, score=0.964 total time=   0.9s
# [CV 5/5] END learning_rate=1, loss=square, n_estimators=100;, score=0.970 total time=   0.4s
# [CV 1/5] END learning_rate=1, loss=square, n_estimators=200;, score=0.971 total time=   0.8s
# [CV 2/5] END learning_rate=1, loss=square, n_estimators=200;, score=0.961 total time=   0.6s
# [CV 3/5] END learning_rate=1, loss=square, n_estimators=200;, score=0.973 total time=   0.7s
# [CV 4/5] END learning_rate=1, loss=square, n_estimators=200;, score=0.968 total time=   0.6s
# [CV 5/5] END learning_rate=1, loss=square, n_estimators=200;, score=0.970 total time=   1.0s
# [CV 1/5] END learning_rate=1.5, loss=linear, n_estimators=50;, score=0.968 total time=   0.3s
# [CV 2/5] END learning_rate=1.5, loss=linear, n_estimators=50;, score=0.958 total time=   0.2s
# [CV 3/5] END learning_rate=1.5, loss=linear, n_estimators=50;, score=0.968 total time=   0.2s
# [CV 4/5] END learning_rate=1.5, loss=linear, n_estimators=50;, score=0.962 total time=   0.2s
# [CV 5/5] END learning_rate=1.5, loss=linear, n_estimators=50;, score=0.963 total time=   0.2s
# [CV 1/5] END learning_rate=1.5, loss=linear, n_estimators=100;, score=0.967 total time=   0.2s
# [CV 2/5] END learning_rate=1.5, loss=linear, n_estimators=100;, score=0.961 total time=   0.4s
# [CV 3/5] END learning_rate=1.5, loss=linear, n_estimators=100;, score=0.971 total time=   0.7s
# [CV 4/5] END learning_rate=1.5, loss=linear, n_estimators=100;, score=0.964 total time=   0.3s
# [CV 5/5] END learning_rate=1.5, loss=linear, n_estimators=100;, score=0.967 total time=   0.3s
# [CV 1/5] END learning_rate=1.5, loss=linear, n_estimators=200;, score=0.968 total time=   0.6s
# [CV 2/5] END learning_rate=1.5, loss=linear, n_estimators=200;, score=0.961 total time=   0.7s
# [CV 3/5] END learning_rate=1.5, loss=linear, n_estimators=200;, score=0.972 total time=   0.7s
# [CV 4/5] END learning_rate=1.5, loss=linear, n_estimators=200;, score=0.966 total time=   1.1s
# [CV 5/5] END learning_rate=1.5, loss=linear, n_estimators=200;, score=0.968 total time=   1.1s
# [CV 1/5] END learning_rate=1.5, loss=square, n_estimators=50;, score=0.971 total time=   0.2s
# [CV 2/5] END learning_rate=1.5, loss=square, n_estimators=50;, score=0.964 total time=   0.3s
# [CV 3/5] END learning_rate=1.5, loss=square, n_estimators=50;, score=0.972 total time=   0.3s
# [CV 4/5] END learning_rate=1.5, loss=square, n_estimators=50;, score=0.966 total time=   0.3s
# [CV 5/5] END learning_rate=1.5, loss=square, n_estimators=50;, score=0.969 total time=   0.3s
# [CV 1/5] END learning_rate=1.5, loss=square, n_estimators=100;, score=0.974 total time=   0.6s
# [CV 2/5] END learning_rate=1.5, loss=square, n_estimators=100;, score=0.962 total time=   0.3s
# [CV 3/5] END learning_rate=1.5, loss=square, n_estimators=100;, score=0.973 total time=   0.3s
# [CV 4/5] END learning_rate=1.5, loss=square, n_estimators=100;, score=0.964 total time=   0.4s
# [CV 5/5] END learning_rate=1.5, loss=square, n_estimators=100;, score=0.969 total time=   0.2s
# [CV 1/5] END learning_rate=1.5, loss=square, n_estimators=200;, score=0.974 total time=   0.4s
# [CV 2/5] END learning_rate=1.5, loss=square, n_estimators=200;, score=0.964 total time=   0.4s
# [CV 3/5] END learning_rate=1.5, loss=square, n_estimators=200;, score=0.975 total time=   0.4s
# [CV 4/5] END learning_rate=1.5, loss=square, n_estimators=200;, score=0.969 total time=   0.4s
# [CV 5/5] END learning_rate=1.5, loss=square, n_estimators=200;, score=0.972 total time=   0.4s
# [CV 1/5] END learning_rate=2, loss=linear, n_estimators=50;, score=0.967 total time=   0.1s
# [CV 2/5] END learning_rate=2, loss=linear, n_estimators=50;, score=0.955 total time=   0.1s
# [CV 3/5] END learning_rate=2, loss=linear, n_estimators=50;, score=0.971 total time=   0.1s
# [CV 4/5] END learning_rate=2, loss=linear, n_estimators=50;, score=0.964 total time=   0.1s
# [CV 5/5] END learning_rate=2, loss=linear, n_estimators=50;, score=0.970 total time=   0.1s
# [CV 1/5] END learning_rate=2, loss=linear, n_estimators=100;, score=0.969 total time=   0.2s
# [CV 2/5] END learning_rate=2, loss=linear, n_estimators=100;, score=0.959 total time=   0.2s
# [CV 3/5] END learning_rate=2, loss=linear, n_estimators=100;, score=0.971 total time=   0.2s
# [CV 4/5] END learning_rate=2, loss=linear, n_estimators=100;, score=0.968 total time=   0.2s
# [CV 5/5] END learning_rate=2, loss=linear, n_estimators=100;, score=0.968 total time=   0.2s
# [CV 1/5] END learning_rate=2, loss=linear, n_estimators=200;, score=0.971 total time=   0.3s
# [CV 2/5] END learning_rate=2, loss=linear, n_estimators=200;, score=0.961 total time=   0.4s
# [CV 3/5] END learning_rate=2, loss=linear, n_estimators=200;, score=0.973 total time=   0.4s
# [CV 4/5] END learning_rate=2, loss=linear, n_estimators=200;, score=0.969 total time=   0.4s
# [CV 5/5] END learning_rate=2, loss=linear, n_estimators=200;, score=0.971 total time=   0.4s
# [CV 1/5] END learning_rate=2, loss=square, n_estimators=50;, score=0.955 total time=   0.1s
# [CV 2/5] END learning_rate=2, loss=square, n_estimators=50;, score=0.965 total time=   0.1s
# [CV 3/5] END learning_rate=2, loss=square, n_estimators=50;, score=0.971 total time=   0.1s
# [CV 4/5] END learning_rate=2, loss=square, n_estimators=50;, score=0.952 total time=   0.1s
# [CV 5/5] END learning_rate=2, loss=square, n_estimators=50;, score=0.966 total time=   0.1s
# [CV 1/5] END learning_rate=2, loss=square, n_estimators=100;, score=0.970 total time=   0.2s
# [CV 2/5] END learning_rate=2, loss=square, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 3/5] END learning_rate=2, loss=square, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 4/5] END learning_rate=2, loss=square, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 5/5] END learning_rate=2, loss=square, n_estimators=100;, score=0.972 total time=   0.2s
# [CV 1/5] END learning_rate=2, loss=square, n_estimators=200;, score=0.966 total time=   0.4s
# [CV 2/5] END learning_rate=2, loss=square, n_estimators=200;, score=0.959 total time=   0.4s
# [CV 3/5] END learning_rate=2, loss=square, n_estimators=200;, score=0.966 total time=   0.4s
# [CV 4/5] END learning_rate=2, loss=square, n_estimators=200;, score=0.968 total time=   0.4s
# [CV 5/5] END learning_rate=2, loss=square, n_estimators=200;, score=0.970 total time=   0.5s
# [CV 1/5] END learning_rate=2.5, loss=linear, n_estimators=50;, score=0.974 total time=   0.1s
# [CV 2/5] END learning_rate=2.5, loss=linear, n_estimators=50;, score=0.958 total time=   0.1s
# [CV 3/5] END learning_rate=2.5, loss=linear, n_estimators=50;, score=0.970 total time=   0.1s
# [CV 4/5] END learning_rate=2.5, loss=linear, n_estimators=50;, score=0.968 total time=   0.1s
# [CV 5/5] END learning_rate=2.5, loss=linear, n_estimators=50;, score=0.969 total time=   0.2s
# [CV 1/5] END learning_rate=2.5, loss=linear, n_estimators=100;, score=0.970 total time=   0.3s
# [CV 2/5] END learning_rate=2.5, loss=linear, n_estimators=100;, score=0.964 total time=   0.3s
# [CV 3/5] END learning_rate=2.5, loss=linear, n_estimators=100;, score=0.974 total time=   0.3s
# [CV 4/5] END learning_rate=2.5, loss=linear, n_estimators=100;, score=0.967 total time=   0.3s
# [CV 5/5] END learning_rate=2.5, loss=linear, n_estimators=100;, score=0.970 total time=   0.3s
# [CV 1/5] END learning_rate=2.5, loss=linear, n_estimators=200;, score=0.973 total time=   0.6s
# [CV 2/5] END learning_rate=2.5, loss=linear, n_estimators=200;, score=0.962 total time=   0.5s
# [CV 3/5] END learning_rate=2.5, loss=linear, n_estimators=200;, score=0.974 total time=   0.4s
# [CV 4/5] END learning_rate=2.5, loss=linear, n_estimators=200;, score=0.968 total time=   0.4s
# [CV 5/5] END learning_rate=2.5, loss=linear, n_estimators=200;, score=0.972 total time=   0.4s
# [CV 1/5] END learning_rate=2.5, loss=square, n_estimators=50;, score=0.932 total time=   0.1s
# [CV 2/5] END learning_rate=2.5, loss=square, n_estimators=50;, score=0.907 total time=   0.1s
# [CV 3/5] END learning_rate=2.5, loss=square, n_estimators=50;, score=0.917 total time=   0.1s
# [CV 4/5] END learning_rate=2.5, loss=square, n_estimators=50;, score=0.833 total time=   0.1s
# [CV 5/5] END learning_rate=2.5, loss=square, n_estimators=50;, score=0.737 total time=   0.1s
# [CV 1/5] END learning_rate=2.5, loss=square, n_estimators=100;, score=0.874 total time=   0.2s
# [CV 2/5] END learning_rate=2.5, loss=square, n_estimators=100;, score=0.931 total time=   0.2s
# [CV 3/5] END learning_rate=2.5, loss=square, n_estimators=100;, score=0.909 total time=   0.2s
# [CV 4/5] END learning_rate=2.5, loss=square, n_estimators=100;, score=0.924 total time=   0.2s
# [CV 5/5] END learning_rate=2.5, loss=square, n_estimators=100;, score=0.765 total time=   0.2s
# [CV 1/5] END learning_rate=2.5, loss=square, n_estimators=200;, score=0.878 total time=   0.4s
# [CV 2/5] END learning_rate=2.5, loss=square, n_estimators=200;, score=0.774 total time=   0.4s
# [CV 3/5] END learning_rate=2.5, loss=square, n_estimators=200;, score=0.898 total time=   0.4s
# [CV 4/5] END learning_rate=2.5, loss=square, n_estimators=200;, score=0.748 total time=   0.4s
# [CV 5/5] END learning_rate=2.5, loss=square, n_estimators=200;, score=0.817 total time=   0.4s
# GridSearchCV(cv=5, estimator=AdaBoostRegressor(),
#              param_grid={'learning_rate': [0.001, 0.1, 1, 1.5, 2, 2.5],
#                          'loss': ['linear', 'square'],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
reg.best_params_
# Out:
# {'learning_rate': 1.5, 'loss': 'square', 'n_estimators': 200}

# %%
reg.best_score_
# Out:
# 0.9707889024593896
