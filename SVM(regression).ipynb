# %% [markdown]
# <a href="https://colab.research.google.com/github/Hellokrrish/Machine-Learning/blob/main/SVM(regression).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import make_regression
x,y=make_regression(n_samples=1000,n_features=2,n_targets=1,noise=0.3)

# %%
x
# Out:
# array([[-0.40943006,  2.05220222],
#        [-0.18014955,  1.16639495],
#        [ 0.40791775,  0.67111447],
#        ...,
#        [ 0.33275164,  0.81624018],
#        [ 0.23536131,  0.44894035],
#        [ 0.50416489, -0.23283853]])

# %%
y
# Out:
# array([ 1.22337364e+02,  7.21516370e+01,  6.93856767e+01,  1.50339098e+02,
#        -1.56243006e+01,  7.58464395e+01,  3.99166538e+01,  5.78949314e+01,
#         1.29586231e+01,  6.89853569e+01,  7.69207281e+01,  1.42849710e+02,
#         1.51643390e+02,  5.22964203e+01,  3.53804928e+01, -5.33196362e+00,
#        -1.42240996e+01,  1.40022216e+02, -7.29304998e+01, -1.10548340e+02,
#        -6.92631709e+01,  2.25887226e+02, -5.58216353e+01, -1.29779000e+01,
#         9.64205058e+01,  4.03533502e+00, -8.36226931e+01, -8.18170186e+00,
#         2.74631964e+01, -3.81047358e+01, -5.73152362e+01,  3.92207216e+01,
#         2.33031449e+00, -4.94496992e+01, -1.43136406e+01, -1.91180523e+01,
#         4.32610952e+01,  1.02057911e+02,  3.51482969e+01,  6.29940585e+01,
#        -4.49293275e+01,  8.47006267e+01,  3.81404815e+01, -1.02802191e+02,
#         6.71798226e+01,  1.57865043e+02,  1.33477755e+02,  9.22008837e+01,
# ...

# %%
sns.scatterplot(x=pd.DataFrame(x)[0],y=pd.DataFrame(x)[1],hue=y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
x_train
# Out:
# array([[ 1.29509962,  1.58481001],
#        [-0.43268032, -0.56693258],
#        [ 0.59741036,  1.97008973],
#        ...,
#        [ 0.22950095,  3.02727337],
#        [ 1.4423778 ,  0.7378658 ],
#        [ 1.06295644,  0.62248272]])

# %%
x_test
# Out:
# array([[-2.12158310e-01, -2.88738649e-01],
#        [ 2.12451480e+00, -1.02014312e+00],
#        [-5.91003275e-01,  1.16000919e+00],
#        [-6.55628598e-02, -6.40521407e-01],
#        [ 1.04818287e+00,  1.49289219e+00],
#        [ 1.09356234e+00,  3.93031623e-01],
#        [-1.04137189e+00,  2.21049329e-01],
#        [-2.94935994e-01,  1.32991804e+00],
#        [-3.22852095e-01,  1.82132320e+00],
#        [ 7.54122929e-01, -2.37141268e+00],
#        [ 7.04468386e-01, -1.48888950e+00],
#        [-8.62247918e-03, -2.88747219e-01],
#        [ 1.19558451e+00, -6.42039542e-01],
#        [-3.18637842e-01,  3.50837398e-01],
#        [-3.66212844e-02, -2.33630584e+00],
#        [-1.30597471e-02,  1.54260295e+00],
#        [-8.91568367e-01,  1.34921055e+00],
#        [-1.02417096e+00,  1.36809352e+00],
#        [ 1.04962792e+00,  1.16697063e+00],
#        [-3.77079648e+00, -2.07946855e-01],
#        [ 8.87065220e-01,  5.59643128e-01],
#        [-7.81749877e-01,  1.71401860e-01],
# ...

# %%
from sklearn.svm import SVR
svr=SVR(kernel='linear')

# %%
svr.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
y_pred=svr.predict(x_test)

# %%
y_pred
# Out:
# array([ -31.98297548,   44.78020125,   49.27724301,  -48.71653582,
#         162.72253365,   87.7323403 ,  -41.59562599,   77.50148753,
#         110.58673984, -125.64976105,  -66.20499434,  -20.80903494,
#          20.41615379,    7.22713987, -166.59011398,  107.96004961,
#          46.10421317,   40.1542968 ,  139.84175015, -221.66815856,
#          88.13245704,  -30.83933638,  -95.67117255,  -75.56602473,
#         104.85921547, -254.196694  , -117.17918934,  -64.622375  ,
#         -55.72921644,   -0.26490562,  137.19748635,  -94.70740887,
#         -82.47232   ,  -29.16361114,   60.67500007,   34.43630298,
#         -14.01101888,   24.18572025,   51.68104947,   47.6691064 ,
#         -65.38327959,   31.01945026,   39.79083817,   -8.0855349 ,
#        -104.9244878 ,  160.53177428,   84.2796933 ,   84.90098293,
#         111.06768274,  110.01201002,  135.98377527,  -13.88910587,
#          89.74037014,  -19.29264639,  144.06146276,   17.00978663,
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9999889622378909

# %%
from sklearn.model_selection import GridSearchCV
params={'C':[1,2,3,4,5,100],
        'gamma':[0.1,0.2,0.5],
        'kernel':['linear'],
        'epsilon':[0.1,0.01,0.2,0.3]}

# %%
params
# Out:
# {'C': [1, 2, 3, 4, 5, 100],
#  'gamma': [0.1, 0.2, 0.5],
#  'kernel': ['linear'],
#  'epsilon': [0.1, 0.01, 0.2, 0.3]}

# %%
grid=GridSearchCV(SVR(),param_grid=params,cv=5,verbose=3)
grid
# Out:
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [1, 2, 3, 4, 5, 100],
#                          'epsilon': [0.1, 0.01, 0.2, 0.3],
#                          'gamma': [0.1, 0.2, 0.5], 'kernel': ['linear']},
#              verbose=3)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5] END C=1, epsilon=0.1, gamma=0.1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.1, gamma=0.1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.1, gamma=0.1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.1, gamma=0.1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.1, gamma=0.1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.1, gamma=0.2, kernel=linear;, score=1.000 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.1, gamma=0.2, kernel=linear;, score=1.000 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.1, gamma=0.2, kernel=linear;, score=1.000 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.1, gamma=0.2, kernel=linear;, score=1.000 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.1, gamma=0.2, kernel=linear;, score=1.000 total time=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'C': 100, 'epsilon': 0.2, 'gamma': 0.1, 'kernel': 'linear'}

# %%
grid.best_score_
# Out:
# 0.9999881308042408
