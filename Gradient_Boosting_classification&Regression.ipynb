# %% [markdown]
# <a href="https://colab.research.google.com/github/Hellokrrish/Machine-Learning/blob/main/Gradient_Boosting_classification%26Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,r2_score

import warnings
warnings.filterwarnings('ignore')

# %%
x,y=make_classification(n_samples=1000,n_features=20,n_classes=2,random_state=1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=1)

# %%
classifier=GradientBoostingClassifier()

# %%
classifier.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred=classifier.predict(x_test)
print('accuracy_score',accuracy_score(y_test,y_pred))
print('classification_report',classification_report(y_test,y_pred))
print('confusion_matrix',confusion_matrix(y_test,y_pred))
print('r2_score',r2_score(y_test,y_pred))
# Out:
# accuracy_score 0.8575757575757575
# classification_report               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       154
#            1       0.87      0.86      0.87       176
#
#     accuracy                           0.86       330
#    macro avg       0.86      0.86      0.86       330
# weighted avg       0.86      0.86      0.86       330
#
# confusion_matrix [[132  22]
#  [ 25 151]]
# r2_score 0.4277597402597403

# %%
# Hyper_paramertuning:
from sklearn.model_selection import GridSearchCV
param_grid={'n_estimators':[50,100,200],
            'learning_rate':[0.001,0.1,1,1.5,2,2.5]
            }
grd=GradientBoostingClassifier()
clf=GridSearchCV(estimator=grd,param_grid=param_grid,cv=5,verbose=3)
clf
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.001, 0.1, 1, 1.5, 2, 2.5],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
clf.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END learning_rate=0.001, n_estimators=50;, score=0.799 total time=   0.3s
# [CV 2/5] END learning_rate=0.001, n_estimators=50;, score=0.806 total time=   0.3s
# [CV 3/5] END learning_rate=0.001, n_estimators=50;, score=0.776 total time=   0.3s
# [CV 4/5] END learning_rate=0.001, n_estimators=50;, score=0.806 total time=   0.3s
# [CV 5/5] END learning_rate=0.001, n_estimators=50;, score=0.754 total time=   0.3s
# [CV 1/5] END learning_rate=0.001, n_estimators=100;, score=0.888 total time=   0.6s
# [CV 2/5] END learning_rate=0.001, n_estimators=100;, score=0.858 total time=   0.6s
# [CV 3/5] END learning_rate=0.001, n_estimators=100;, score=0.776 total time=   0.6s
# [CV 4/5] END learning_rate=0.001, n_estimators=100;, score=0.806 total time=   0.6s
# [CV 5/5] END learning_rate=0.001, n_estimators=100;, score=0.806 total time=   0.6s
# ...

# %%
clf.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 50}

# %%
clf.best_score_
# Out:
# 0.8582089552238805

# %%
# Regression:
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score

# %%
x,y=make_regression(n_samples=1000,n_features=2,noise=10,random_state=1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=1)

# %%
reg=GradientBoostingRegressor()
reg
# Out:
# GradientBoostingRegressor()

# %%
reg.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred=reg.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.9823439012650179

# %%
# Hyper_paramertuning:
from sklearn.model_selection import GridSearchCV
param_grid={'n_estimators':[50,100,200],
            'learning_rate':[0.001,0.1,1,1.5,2,2.5]
            }
gdr=GradientBoostingRegressor()
reg=GridSearchCV(estimator=gdr,param_grid=param_grid,cv=5,verbose=3)
reg
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.001, 0.1, 1, 1.5, 2, 2.5],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
reg.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END learning_rate=0.001, n_estimators=50;, score=0.058 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, n_estimators=50;, score=0.054 total time=   0.1s
# [CV 3/5] END learning_rate=0.001, n_estimators=50;, score=0.093 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, n_estimators=50;, score=0.088 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, n_estimators=50;, score=0.085 total time=   0.1s
# [CV 1/5] END learning_rate=0.001, n_estimators=100;, score=0.139 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, n_estimators=100;, score=0.135 total time=   0.1s
# [CV 3/5] END learning_rate=0.001, n_estimators=100;, score=0.176 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, n_estimators=100;, score=0.170 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, n_estimators=100;, score=0.166 total time=   0.1s
# ...

# %%
reg.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 100}

# %%
reg.best_score_
# Out:
# 0.9835307272358944
